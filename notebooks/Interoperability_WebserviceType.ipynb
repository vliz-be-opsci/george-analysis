# %% [markdown]
# # Interoperability Assessment by Service Type

# %% [markdown]
# ## Analysis methods & results
#
# Starting from the [overview of dataservices](Overview_ServiceEndpoints.ipynb)
#
# Data services were categorized into different types based on ...
# and assessed for their interoperability.
#
# *In the FAIRness & interoperability assessment we took following key considerations into account:*
# *- Standardization:*
# *Services that adhere to widely accepted standards (like SPARQL and JSON) are generally more interoperable.*
# *- Data Format:*
# *Services that provide data in structured, machine-readable formats are more interoperable than those that rely on raw file sharing.*
# *- Integration Complexity:*
# *The ease with which a service can be integrated with other systems affects its interoperability.*
# *More specifically, how easily the data is accessible and its semantics understandable.*
#
#
# These analyses can be consulted in the jupyter notebooks.

# %% [markdown]
# ### 1. HTTPS Server
# Basic file-hosting service, often used for static file distribution (e.g., NetCDF, CSV).
#
# | Dimension              | Evaluation |
# |------------------------|------------|
# | Protocol               | HTTP/FTP (read-only, no API logic) |
# | File discovery         | Manual or directory scraping |
# | Metadata exposure      | Often missing or embedded in files |
# | Format                 | May support standard formats (NetCDF, CSV) |
# | Integration effort     | High — often no structured metadata, requires parsing |
# | Interoperability rating| ⭐ Low — poor automation support |
# | Comments               | Suitable for archival or download, but not interoperable |
#
# - File Server:
#     - Interoperability: Low
#     - 2 stars
#     - Explanation:
#         - File servers primarily store and share files, in formats like text, CSV or NetCDF.
#         - Accessing data requires additional steps (constructing uri template pattern to retrieve data via ftp)
#         - While the data is accessible, the lack of structured, queryable interfaces means that other systems must download and process the files before they can use the data, which limits interoperability.
#
#
# GEORGE endpoints of this type:
# - https://data-argo.ifremer.fr/
#
# Notebooks:
# - [ARGO-FileServer](ARGO-FileServer.ipynb)

# %% [markdown]
# ### 2. FTP Server
#
# ???
#
# GEORGE endpoints of this type:
# - ftp://ftp.ifremer.fr/ifremer/glider/v2
#
# Notebooks:
# - None (manually assessed)

# %% [markdown]
# ### 3. S3 Server
#
# ???
#
# GEORGE endpoints of this type:
# - https://registry.opendata.aws/argo-gdac-marinedata/
#
# Notebooks:
# - None (manually assessed)

# %% [markdown]
# ### 4. Open Search
#
# ???
#
# GEORGE endpoints of this type:
# - https://opensearch.ifremer.fr/html
#
# Notebooks:
# - None (manually assessed)

# %% [markdown]
# ### 5. ERDDAP Server
#
# Open-source data server for gridded and tabular scientific data with built-in API support.
#
# | Dimension              | Evaluation |
# |------------------------|------------|
# | Protocol               | RESTful; supports OPeNDAP, JSON, CSV |
# | Machine-readability    | ✔️ High — structured formats, queryable |
# | Metadata standards     | ✔️ CF-compliant NetCDF metadata |
# | Semantic compliance    | ⚠️ Limited — standard names, not full ontologies |
# | Discoverability        | ✔️ Via catalog and JSON/HTML endpoints |
# | Integration effort     | Low — designed for automation |
# | Interoperability rating| ⭐⭐⭐⭐ |
# | Comments               | Ideal for harmonization and integration tasks |
#
# - ERDDAP Server:
#     - Interoperability: Medium (~ possibly high if metadata contains links to e.g. BODC terms)
#     - 3 stars
#     - Explanation:
#         - ERDDAP (Environmental Research Division's Data Access Program) server provides data in mainly NetCDF formats.
#         - analysis of alignment between properties between the ERDDAP servers shows a degree of similarity in naming, but the majority of properties appear to be unique.
#         - due to limited use of persistent identifiers and standard terms, there remains a great deal a semantic ambiguity and therefore limiting interoperability.
#         - ERDDAP servers offer more interoperability than a file server because it can support a variety of output formats and standard protocols, allowing for easier integration with other systems. However, the different servers offer a variety in properties with sometimes unclear semantics, which limits interoperability.
#
#
# GEORGE endpoints of this type:
# - https://erddap.ifremer.fr/erddap/tabledap/ArgoFloats-synthetic-BGC.graph
# - https://erddap.ifremer.fr/erddap/tabledap/OceanGlidersGDACTrajectories.html
# - https://erddap.emso.eu/erddap
#
# Notebooks:
# - [ARGO-ERDDAP](ARGO-ERDDAP.ipynb)
# - [EMSO-ERDDAP](EMSO-ERDDAP.ipynb)

# %% [markdown]
# ### 6. OGC SensorThings API
#
# OGC standard API for representing IoT sensor data and metadata.
#
# | Dimension              | Evaluation |
# |------------------------|------------|
# | Protocol               | REST + JSON (OData standard) |
# | Service structure      | Standardized entities (Thing, Sensor, Observation, etc.) |
# | Metadata exposure      | ✔️ Available via entity links |
# | Semantic richness      | ⚠️ Depends on implementation (vocabularies often custom) |
# | Discoverability        | ✔️ Supports `$filter`, `$expand`, etc. |
# | Integration effort     | Medium — model alignment needed |
# | Interoperability rating| ⭐⭐⭐ |
# | Comments               | Flexible and scalable for real-time data; requires alignment effort |
#
# - JSON APIs:
#     - Interoperability: High
#     - 3 stars
#     - Explanation:
#         - JSON APIs provide data in a structured format (JSON), which is widely used and easy to consume across various platforms and programming languages.
#         - the API design and data models follow standard protocols (e.g. SensorThings protocol, Swagger API documentation) which facilitates integration of data into other applications, mobile apps and systems.
#         - Some occurrence of URLs and standard terms, but overall limited use of persistent identifiers hinders interoperability.
#
# GEORGE endpoints of this type:
# - https://sextant.ifremer.fr/examind/WS/sts/coriolis/v1.1
#
# Notebooks:
# - [ARGO-OGCSensorThings](ARGO-OGCSensorThings.ipynb)

# %% [markdown]
# ### 7. SPARQL Endpoint
#
# Semantic Web service for complex metadata queries using RDF and ontologies.
#
# | Dimension              | Evaluation |
# |------------------------|------------|
# | Protocol               | SPARQL 1.1 (RDF query language) |
# | Machine-readability    | ✔️ RDF/XML, Turtle, JSON-LD |
# | Vocabulary use         | ✔️ Common ontologies (e.g., DCAT, SOSA, SKOS) |
# | Semantic richness      | ⭐⭐⭐⭐⭐ — core strength |
# | Query complexity       | High — powerful but has learning curve |
# | Integration effort     | Medium to High — depends on data modeling |
# | Interoperability rating| ⭐⭐⭐⭐ |
# | Comments               | Excellent for linking metadata; less suited for raw data streams |
#
#
# - SPARQL Endpoint:
#     - Interoperability: Very High
#     - 4 stars
#     - Explanation:
#         - A SPARQL endpoint provides a way to query RDF (Resource Description Framework) data using the SPARQL query language. RDF is a standard model for data interchange on the web, and SPARQL is a W3C-standardized query language.
#         - This combination allows for highly interoperable data sharing across different systems, particularly in the context of linked data and the Semantic Web.
#         - SPARQL endpoints are particularly powerful in environments where data integration from multiple sources is required.
#
# GEORGE endpoints of this type:
# - https://sparql.ifremer.fr/argo/query
# - https://meta.icos-cp.eu/sparqlclient/?type=CSV
#
# Notebooks:
# - [ARGO-SPARQL-endpoint](ARGO-SPARQL-endpoint.ipynb)
# - [ICOS-SPARQL-endpoint](ICOS-SPARQL-endpoint.ipynb)

# %% [markdown]
# ### 8. RESTful JSON API (Custom)
#
# Typical web services providing data via JSON, often not standardized.
#
# | Dimension              | Evaluation |
# |------------------------|------------|
# | Protocol               | REST over HTTP |
# | Machine-readability    | ✔️ JSON — easy to parse |
# | Metadata exposure      | ⚠️ Often limited or undocumented |
# | Vocabulary use         | ❌ Custom field names, non-standard |
# | Discoverability        | ⚠️ Relies on good documentation |
# | Integration effort     | High — manual mapping required |
# | Interoperability rating| ⭐⭐ |
# | Comments               | Needs strong documentation or wrapping for reuse in research systems |
#
#
# - JSON APIs:
#     - Interoperability: High
#     - 3 stars
#     - Explanation:
#         - JSON APIs provide data in a structured format (JSON), which is widely used and easy to consume across various platforms and programming languages.
#         - the API design and data models follow standard protocols (e.g. SensorThings protocol, Swagger API documentation) which facilitates integration of data into other applications, mobile apps and systems.
#         - Some occurrence of URLs and standard terms, but overall limited use of persistent identifiers hinders interoperability.
#
# GEORGE endpoints of this type:
# - https://fleetmonitoring.euro-argo.eu/swagger-ui.html
# - https://dataselection.euro-argo.eu/swagger-ui.html#/
#
# Notebooks:
# - [ARGO-jsonAPIs](ARGO-jsonAPIs.ipynb)

# %% [markdown]
# ### 9. Data portal
#
# ??
#
# GEORGE endpoints of this type:
# - https://data.icos-cp.eu/portal/
#
# Notebooks:
# - None (manually assessed)

# %% [markdown]
# ## 🧭 Summary Table - To be updated!!
#
# | Service Type        | Interop Strength | Metadata Quality | Semantic Alignment | Integration Effort |
# |---------------------|------------------|------------------|--------------------|--------------------|
# | HTTP/FTP Server     | 🔸 Low           | ❌ Poor          | ❌ None             | 🔺 High            |
# | ERDDAP              | ⭐⭐⭐⭐           | ✔️ Good         | ⚠️ Basic           | ✅ Low             |
# | SensorThings API    | ⭐⭐⭐            | ✔️ Structured    | ⚠️ Varies          | ⚠️ Medium          |
# | SPARQL Endpoint     | ⭐⭐⭐⭐           | ⭐⭐⭐⭐           | ⭐⭐⭐⭐              | 🔺 High            |
# | REST JSON API       | ⭐⭐             | ⚠️ Minimal       | ❌ Custom          | 🔺 High            |
