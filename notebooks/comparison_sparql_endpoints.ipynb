# %%
import pandas as pd

# %% [markdown]
# ### Comparing the properties between SPARQL endpoints (EUROARGO & ICOS SPARQL endpoints)

# %% [markdown]
# ## example:
# I want to compare the location of sites available through both the EUROARGO SPARQL endpoint and ICOS SPARQL endpoint
# - Do they offer same and/or different locations?
# - Do locations with the same name have the same geographic latitude and longtitude? (~ is metadata similar between sites?)
#
# 1 a sparql query to retrieve this information from EUROARGO SPARQL endpoint
# 2 a different SPARQL query to retrieve this info from ICOS SPARQL endpoint
#
# 3 assuming that this represents the same (note: since these are modelled through different classes, that are not linked with each other in th eontology descriptions)
# 4 realizing this returns different metadata

# %% [markdown]
# note: the example above is comparing stations;
# this doesn't yet represent integration of data such as e.g. sensor observation measurements
# --> this is also hindered by current data granularity of both endpoints
# - ARGO easily redirects to actual download of data
# - ICOS includes a description of data structure as metadata

# %% [markdown]
# ## Analysis results
#
# - querying the SPARQL endpoint requires knowledge on the data model ~ data models are institute specific.... ~ making it more difficult to combine data
